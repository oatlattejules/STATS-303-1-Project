# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/juliannawang/Desktop/archive/2022/heart_2022_no_nans.csv', usecols=[
    'State','GeneralHealth','PhysicalActivities','SleepHours','HadHeartAttack','HadAngina','HadStroke',
    'HadAsthma','HadSkinCancer','HadCOPD','HadDepressiveDisorder','HadKidneyDisease','HadArthritis','HadDiabetes',
    'SmokerStatus','ECigaretteUsage','AgeCategory','WeightInKilograms','BMI','AlcoholDrinkers','DeafOrHardOfHearing',
    'BlindOrVisionDifficulty'])
data.head()
# Out:
#      State GeneralHealth PhysicalActivities  SleepHours HadHeartAttack  \
# 0  Alabama     Very good                Yes         9.0             No
# 1  Alabama     Very good                Yes         6.0             No
# 2  Alabama     Very good                 No         8.0             No
# 3  Alabama          Fair                Yes         9.0             No
# 4  Alabama          Good                Yes         5.0             No
#
#   HadAngina HadStroke HadAsthma HadSkinCancer HadCOPD  ... HadArthritis  \
# 0        No        No        No            No      No  ...          Yes
# 1        No        No        No            No      No  ...          Yes
# 2        No        No        No            No      No  ...          Yes
# 3        No        No        No           Yes      No  ...          Yes
# 4        No        No        No            No      No  ...          Yes
#
#   HadDiabetes DeafOrHardOfHearing BlindOrVisionDifficulty   SmokerStatus  \
# 0          No                  No                      No  Former smoker
# 1         Yes                  No                      No  Former smoker
# 2          No                  No                     Yes  Former smoker
# 3          No                  No                      No   Never smoked
# 4          No                  No                      No   Never smoked
#
#                              ECigaretteUsage      AgeCategory  \
# 0  Never used e-cigarettes in my entire life     Age 65 to 69
# 1  Never used e-cigarettes in my entire life     Age 70 to 74
# 2  Never used e-cigarettes in my entire life     Age 75 to 79
# 3  Never used e-cigarettes in my entire life  Age 80 or older
# 4  Never used e-cigarettes in my entire life  Age 80 or older
#
#   WeightInKilograms    BMI  AlcoholDrinkers
# 0             71.67  27.99               No
# 1             95.25  30.13               No
# 2            108.86  31.66              Yes
# 3             90.72  31.32               No
# 4             79.38  33.07               No
#
# [5 rows x 22 columns]

# %% [markdown]
# # Question
# For each state, is there a correlation between other health conditions (diabetes, asthma, arthritis, kidney disease, etc.) and having a heart condition? (heart attack, angina)

# %%
#had diabetes, smokerstatus, ecig usage
